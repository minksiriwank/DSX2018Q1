# %%
# The code was removed by DSX for sharing.
# Out:
#    Region  Country       City Productline       Product Segment     Time  \
# 0  Europe  Germany  Frankfurt       Alpha    Alpha Gold    High  2013-02
# 1  Europe  Germany  Frankfurt       Alpha    Alpha Gold    High  2013-11
# 2  Europe  Germany  Frankfurt       Alpha  Alpha Silver    High  2013-02
# 3  Europe  Germany  Frankfurt       Alpha  Alpha Bronze    High  2013-05
# 4  Europe  Germany  Frankfurt       Alpha  Alpha Bronze    High  2013-10
#
#   Version  Revenue   COGS  RawMaterialCost  Other  Gross Margin  \
# 0  Budget   249574  73064            46621  26443        176510
# 1  Budget   278371  76559            52000  24559        201812
# 2  Budget   199584  58849            44391  14458        140735
# 3  Budget     7514   2428             1749    679          5086
# 4  Budget    20738   6780             4827   1953         13958
#
#    Gross Margin %
# 0        0.707245
# 1        0.724974
# 2        0.705141
# 3        0.676869
# 4        0.673063

# %%
df_data.tail(5)
# Out:
#              Region        Country        City Productline         Product  \
# 1696  North America  United States      Austin        Nova     Nova Bronze
# 1697  North America         Canada     Toronto       Alpha    Alpha Silver
# 1698  North America         Canada     Toronto       Alpha    Alpha Silver
# 1699  North America         Canada     Toronto       Alpha    Alpha Silver
# 1700           Asia          Japan  City-Osaka     Charger  Charger Silver
#
#      Segment     Time Version  Revenue   COGS  RawMaterialCost  Other  \
# 1696  Medium  2013-05  Budget    16022   3158             2856    302
# 1697     Low  2013-04  Budget    24671   7685             5368   2317
# 1698     Low  2013-08  Budget     4111    923              574    349
# 1699     Low  2013-11  Budget     2467   1253              826    427
# 1700     Low  2013-12  Budget    40314  15931            11376   4555
#
#       Gross Margin  Gross Margin %
# 1696         12864        0.802896
# ...

# %%
df_data.shape
# Out:
# (1701, 14)

# %%
import brunel
# %brunel data('df_data') bar x(city) y(revenue) sum(revenue) color(productline) tooltip(revenue):: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/e488ce0d-62f8-4519-9171-f5f9d82c3c00/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/e488ce0d-62f8-4519-9171-f5f9d82c3c00/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
# %brunel data('df_data') x(region) y(productline) chord sum(revenue) size(revenue) tooltip(revenue) color(segment):: width=500, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/e488ce0d-62f8-4519-9171-f5f9d82c3c00/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/e488ce0d-62f8-4519-9171-f5f9d82c3c00/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
# %brunel data('df_data') cloud x(Country) sum(revenue) color(Segment) tooltip(revenue) :: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/e488ce0d-62f8-4519-9171-f5f9d82c3c00/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/e488ce0d-62f8-4519-9171-f5f9d82c3c00/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...
